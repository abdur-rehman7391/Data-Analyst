# %% [markdown]
# <a href="https://colab.research.google.com/github/abdur-rehman7391/Data-Analyst/blob/main/CyberBulling%20Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df0 = pd.read_csv('/content/final_hateXplain.csv')

# %%
df0.head(2)
# Out:
#    Unnamed: 0                                            comment      label  \
# 0           0                     0 u0 lmao wow fuck you too 😂 😂     normal
# 1           1  1 0 th floor maybe wow cnn with the fakenews t...  offensive
#
#       Race      Religion     Gender Sexual_Orientation  Miscellaneous
# 0  No_race  Nonreligious  No_gender     No_orientation  Not Avalaible
# 1  No_race  Nonreligious  No_gender     No_orientation          Other

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='label')
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='Race')
plt.title('Distribution of Race')
plt.xlabel('Race')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='Religion')
plt.title('Distribution of Religion')
plt.xlabel('Religion')
plt.ylabel('Count')
plt.show()


plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='Gender')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()


plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='Sexual_Orientation')
plt.title('Distribution of Sexual Orientation')
plt.xlabel('Sexual Orientation')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(6, 4))
sns.countplot(data=df0, x='Miscellaneous')
plt.title('Distribution of Miscellaneous')
plt.xlabel('Miscellaneous')
plt.ylabel('Count')
plt.show()
