# %% [markdown]
# <a href="https://colab.research.google.com/github/abdur-rehman7391/Using-ML-CyberBulling-/blob/main/K_Mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import csr_matrix

# %%
df = pd.read_csv(r"/content/sample_data/final_hateXplain.csv")
df.head(20)
# Out:
#     Unnamed: 0                                            comment       label  \
# 0            0                     0 u0 lmao wow fuck you too 😂 😂      normal
# 1            1  1 0 th floor maybe wow cnn with the fakenews t...   offensive
# 2            2  1 0 yrs <number> white women raped by niggers ...  hatespeech
# 3            3  1 2 h ago ching chong accepted your friend req...   offensive
# 4            4  1 8 th century mayhem and lawlessness had noth...      normal
# 5            5  1 9 3 0 sgermany geneticjews controlled white ...  hatespeech
# 6            6  1 9 5 0 white america the most peaceful decade...  hatespeech
# 7            7                       1 h de retard au work shessh      normal
# 8            8  1 st wave feminism let us vote and shit asshol...      normal
# 9            9  2 3 andme is a strange choice for this sort of...  hatespeech
# 10          10  2 k do not put out patch notes and you niggers...      normal
# ...

# %%
categorical_cols = ['comment', 'label', 'Race', 'Gender', 'label','Religion','Sexual_Orientation','Miscellaneous']
# for col in categorical_cols:
#     le = LabelEncoder()
#     df[col] = le.fit_transform(df[col])
X = df['comment']
y = df['label']
vec = TfidfVectorizer()
X = vec.fit_transform(X)
y = vec.fit_transform(y)

# %%
print("this is X: ", X, asxis = 1)
#print("this is y: ", y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ce67f3ff1bc> in <cell line: 1>()
# ----> 1 print("this is X: ", X, asxis = 1)
#       2 print("this is y: ", y)
#
# NameError: name 'X' is not defined

# %%
print(X.shape)
print(y.shape)
# Out:
# (20109, 28292)
# (20109, 3)

# %%
plt.scatter(X, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'csr_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d1749f3d45cc> in <cell line: 1>()
# ----> 1 plt.scatter(X, y)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
#plt.scatter(df['comment'], df['label'], df['Race'],df['Religion'])
# Assuming X is a sparse matrix and y is a csr_matrix
if isinstance(X, csr_matrix):
    X = X.toarray()  # Convert sparse matrix to a dense numpy array

if isinstance(y, csr_matrix):
    y = y.toarray()  # Convert csr_matrix to a dense numpy array

# If y is a 2D array, select the first column for plotting
if y.ndim == 2:
    y = y[:, 0]

# Now you can plot the data
plt.scatter(X, y)
plt.xlabel("X values")
plt.ylabel("y values")
plt.title("Scatter Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4a250834d10d> in <cell line: 14>()
#      12
#      13 # Now you can plot the data
# ---> 14 plt.scatter(X, y)
#      15 plt.xlabel("X values")
#      16 plt.ylabel("y values")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

# Assuming 'df' is your DataFrame
X = df['comment']
y = df['label']

vec = TfidfVectorizer()
X = vec.fit_transform(X)  # Transform 'comment' column

#  No need to transform 'label', it's your target variable
# y = vec.fit_transform(y)

# Convert to dense array if needed
if isinstance(X, csr_matrix):
    X = X.toarray()

# If y is multi-dimensional, select the first column
if y.ndim == 2:
    y = y[:, 0]

# Now plot the data
plt.scatter(X[:, 0], y)  # Select the first feature of X for plotting
plt.xlabel("X values")
plt.ylabel("y values")
plt.title("Scatter Plot")
plt.show()
