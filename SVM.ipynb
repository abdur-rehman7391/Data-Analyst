# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score,  classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv(r"E:\Study\Data Analyst\Practice data\CyberBullying Detection Dataset\final_hateXplain.csv")
df.head(9)
# Out:
#    Unnamed: 0                                            comment       label  \
# 0           0                     0 u0 lmao wow fuck you too 😂 😂      normal
# 1           1  1 0 th floor maybe wow cnn with the fakenews t...   offensive
# 2           2  1 0 yrs <number> white women raped by niggers ...  hatespeech
# 3           3  1 2 h ago ching chong accepted your friend req...   offensive
# 4           4  1 8 th century mayhem and lawlessness had noth...      normal
# 5           5  1 9 3 0 sgermany geneticjews controlled white ...  hatespeech
# 6           6  1 9 5 0 white america the most peaceful decade...  hatespeech
# 7           7                       1 h de retard au work shessh      normal
# 8           8  1 st wave feminism let us vote and shit asshol...      normal
#
#         Race      Religion     Gender Sexual_Orientation  Miscellaneous
# 0    No_race  Nonreligious  No_gender     No_orientation  Not Avalaible
# ...

# %%
categorical_cols = ['Race', 'Gender', 'label','Religion','Sexual_Orientation','Miscellaneous']
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
scaler = StandardScaler()

# Fit and transform the numerical data
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df
# Out:
#        Unnamed: 0                                            comment  label  \
# 0       -1.731965                     0 u0 lmao wow fuck you too 😂 😂      1
# 1       -1.731792  1 0 th floor maybe wow cnn with the fakenews t...      2
# 2       -1.731620  1 0 yrs <number> white women raped by niggers ...      0
# 3       -1.731448  1 2 h ago ching chong accepted your friend req...      2
# 4       -1.731276  1 8 th century mayhem and lawlessness had noth...      1
# ...           ...                                                ...    ...
# 20104    1.731276  😂 😂 😂 😂 😂 y ’ all be so mad at caucasians fail...      2
# 20105    1.731448  🤔 🤔 🤔 🤔 mmm yes the trebuchet memes are much n...      0
# 20106    1.731620             🤣 this so ghetto i ’ m ready to get tf      2
# 20107    1.731792  🤣 🤣 😂 😂 🤣 🤣 😂 😂 🤣 🤣 you spelled my name wrong ...      0
# 20108    1.731965  🤨 hm six million but yep they were disarmed ce...      0
#
# ...

# %%
vectorizer = TfidfVectorizer()
X_text = vectorizer.fit_transform(df['comment'])

# %%
X = df.drop(columns=['comment', 'label'])  # Potentially exclude unnecessary columns
y = df['label']

# %%
X_numerical = scaler.fit_transform(X)

# %%
X_numerical
# Out:
# array([[-1.73196468,  0.66976251,  0.50184878, -0.09219634,  0.34648154,
#         -0.3352818 ],
#        [-1.73179241,  0.66976251,  0.50184878, -0.09219634,  0.34648154,
#          1.3123677 ],
#        [-1.73162014, -1.70690837,  0.50184878, -0.09219634,  0.34648154,
#         -0.3352818 ],
#        ...,
#        [ 1.73162014,  0.66976251,  0.50184878, -0.09219634,  0.34648154,
#          1.3123677 ],
#        [ 1.73179241, -1.36738396,  0.50184878, -0.09219634,  0.34648154,
#         -0.3352818 ],
#        [ 1.73196468,  0.66976251, -0.77784652, -0.09219634,  0.34648154,
#         -0.3352818 ]])

# %%
print(X_numerical.shape)
print(X_text.shape)
# Out:
# (20109, 6)
# (20109, 28292)

# %%
X_numerical.reshape(-1, 1)
X_text = X_text.toarray()

# %%
X = np.column_stack((X_numerical, X_text))

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
 random_state=42)

# %%
svm_model = SVC()  # Create an SVC object
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6933532239350241
#               precision    recall  f1-score   support
#
#            0       0.64      0.83      0.72      2000
#            1       0.87      0.74      0.80      2282
#            2       0.56      0.48      0.52      1751
#
#     accuracy                           0.69      6033
#    macro avg       0.69      0.68      0.68      6033
# weighted avg       0.70      0.69      0.69      6033
